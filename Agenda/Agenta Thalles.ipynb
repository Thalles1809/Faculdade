# %% [markdown]
# *  Nome: Thalles Vinicius Franchin Peres Ladeira
# *  Inscrição: 2172190004
# *  Curso: Engenharia de Software

# %% [markdown]
# Função que recebe a variável nome para verificar se existe algum valor igual já cadastrado

# %%
def ext_cnt_nome(lst, nome):
    if len(lst) > 0:
        for cnt in lst:
            if cnt['nome'] == nome:
                return True
    return False

# %% [markdown]
# Função que adiciona novos contatos para um dicionário que será inserida ao final de uma lista

# %%
def adicionar(lst):
    while True:
        nome = str(input("Digite o nome do contato: ")).lower()
        if not ext_cnt_nome(lst, nome):
            break
        else:
            print("Nome já utilizado!\nInsira outro nome")

    cnt = {
        'nome': nome,
        'telefone': str(input("Telefone: ")).lower(),
        'email': str(input("E-mail: ")).lower(),
        'twitter': str(input("Twitter: ")).lower(),
        'instagram': str(input("Instagram: ")).lower()}
    lst.append(cnt)
    print(f"O contato {cnt['nome']} foi cadastrado com sucesso!\n")

# %% [markdown]
# Função que faz a inserção de novos dados em cadastro já inserido anteriormente

# %%
def inserir_novos_dados(cnt):
    cnt['nome'] = str(input(" Novo nome: ")).lower()
    cnt['telefone'] = input(" Telefone do contato: ").lower()
    cnt['email'] = input(" E-mail do contato: ").lower()
    cnt['twitter'] = input(" Twitter do contato: ").lower()
    cnt['instagram'] = input(" Instagram do contato: ").lower()

    print(
        f"\nOs dados do contato {cnt['nome']}, foram alterados com suceso!\n")

# %% [markdown]
# Função que busca o o valor pela chave do dicionário, mostra os atuais dados cadastrados e chama a função que cadastra os novos dados

# %%
def alterar(lst):
    if len(lst) > 0:
        nome = str(input(" O nome do contato a ser alterado: ")).lower()
        if ext_cnt_nome(lst, nome):
            for cnt in lst:
                if cnt['nome'] == nome:
                    print("\n##############################################")
                    print(f"Nome: {cnt['nome']}")
                    print(f"Telefone: {cnt['telefone']}")
                    print(f"Email: {cnt['email']}")
                    print(f"Twitter: {cnt['twitter']}")
                    print(f"Instagram: {cnt['instagram']}")
                    print("#############################################\n")

                    inserir_novos_dados(cnt)
                    break
        else:
            print(f"Não existe contato cadastrado com o nome informado {nome}")
    else:
        print("\n############################################")
        print("    Não existe contato a ser alterado!      ")
        print("############################################\n")

# %% [markdown]
# Função que executa a exclusão do cadastro por índice do dicionário na lista com a função for com enumerate

# %%
def excluir(lst):
    if len(lst) > 0:
        nome = str(input("Digite o nome do contato a ser excluído: ")).lower()
        if ext_cnt_nome(lst, nome):
            for i, cnt in enumerate(lst):
                if cnt["nome"] == nome:
                    print("\n##############################################")
                    print(f"Nome: {cnt['nome']}")
                    print(f"Telefone: {cnt['telefone']}")
                    print(f"Email: {cnt['email']}")
                    print(f"Twitter: {cnt['twitter']}")
                    print(f"Instagram: {cnt['instagram']}")
                    print("##############################################\n")

                    del lst[i]
                    print("O contato foi apagado com sucesso!")
                    break

        else:
            print(f"Não existe contato solicitado com o nome: {nome}\n")
    else:
        print("\n################################################")
        print("Não existe nenhum contato cadastrado no sistema! ")
        print("################################################\n")

# %% [markdown]
# Função para buscar se o contato e escreve-lo na tela

# %%
def buscar(lst):
    if len(lst) > 0:
        nome = input("Digite o nome do contato a ser encontrado: ").lower()
        if ext_cnt_nome(lst, nome):
            for cnt in lst:
                if cnt["nome"] == nome:
                    print("\n##############################################")
                    print(f"Nome: {cnt['nome']}")
                    print(f"Telefone: {cnt['telefone']}")
                    print(f"Email: {cnt['email']}")
                    print(f"Twitter: {cnt['twitter']}")
                    print(f"Instagram: {cnt['instagram']}")
                    print("##############################################\n")
                    break
        else:
            print(
                f"Não existe contato cadastrado no sistema com o email {nome}.\n")
    else:
        print("\n##############################################")
        print("    Nenhum contato cadastrado no sistema!      ")
        print("##############################################\n")

# %% [markdown]
# Função para buscar todos os cadastros e escreve-los em tela com a contagem de quantos cadastros

# %%
def listar(lst):
    if len(lst) > 0:
        for i, cnt in enumerate(lst):
            print("\n##############################################")
            print(f"Contato {i+1}:")
            print(f"\tNome: {cnt['nome']}")
            print(f"\tTelefone: {cnt['telefone']}")
            print(f"\tEmail: {cnt['email']}")
            print(f"\tTwitter: {cnt['twitter']}")
            print(f"\tInstagram: {cnt['instagram']}")
            print("##############################################\n")
    else:
        print("\n###################################################")
        print(" Não existe nenhum contato cadastrado para listar! ")
        print("###################################################\n")

# %% [markdown]
# Função matriz que contém o menu, e as condicioanis que vazem a verificação da opção escolhida pelo usuário

# %%
def main_menu():
    lst = []

    while True:
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        print("---------------------------------")
        print("#####   Agenda Telefônica   #####")
        print("##### 1 - Adicionar contato #####")
        print("##### 2 - Alterar contato   #####")
        print("##### 3 - Excluir contato   #####")
        print("##### 4 - Buscar contato    #####")
        print("##### 5 - listar contato    #####")
        print("##### 6 - Sair              #####")
        print("---------------------------------")
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")

        while True:
            try:
                opc = int(input("\nEscolha uma das opções a seguir ~> "))
                break
            except ValueError:
                print("\nAceito apenas números!\n")

        '''
        Forma de evitar o erro da digitação de caractere
        by: Monitor Samuel
        '''

        if opc == 1:
            adicionar(lst)

        elif opc == 2:
            alterar(lst)

        elif opc == 3:
            excluir(lst)

        elif opc == 4:
            buscar(lst)

        elif opc == 5:
            listar(lst)

        elif opc == 6:
            print("\n###################################################")
            print("Saindo do Programa...\nExecução finalizada com sucesso !")
            print("###################################################\n")
            break
        else:
            print("\n###################################################")
            print("\nOpção inválida.Tente novamente!\n")
            print("###################################################\n")


main_menu()
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 1
# Digite o nome do contato: THALLES
# Telefone: 61985859595
# E-mail: thalles@gmail.com
# Twitter: Thalles1809
# Instagram: 1809Thalles
# O contato thalles foi cadastrado com sucesso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 1
# Digite o nome do contato: Gabriel
# Telefone: 61984849797
# E-mail: gabriel@gmail.com
# Twitter: Gab_s
# Instagram: Gabr_el
# O contato gabriel foi cadastrado com sucesso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 1
# Digite o nome do contato: kathleen
# Telefone: 61952523232
# E-mail: Kath@gmail.com
# Twitter: Kath_leen
# Instagram: Kathle_en
# O contato kathleen foi cadastrado com sucesso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 1
# Digite o nome do contato: Pedro
# Telefone: 61945457445
# E-mail: Pedro@gmail.com
# Twitter: Pedr_o
# Instagram: Pe_dro
# O contato pedro foi cadastrado com sucesso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 1
# Digite o nome do contato: Kimmy
# Telefone: 61985653221
# E-mail: Kimmy@gmail.com
# Twitter: KimmyArtemis
# Instagram: Kimm_y
# O contato kimmy foi cadastrado com sucesso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 1
# Digite o nome do contato: Nivs
# Telefone: 11985856363
# E-mail: Nivs@gmail.com
# Twitter: Niv_s
# Instagram: Nivan_Junior
# O contato nivs foi cadastrado com sucesso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 5
#
# ##############################################
# Contato 1:
# 	Nome: thalles
# 	Telefone: 61985859595
# 	Email: thalles@gmail.com
# 	Twitter: thalles1809
# 	Instagram: 1809thalles
# ##############################################
#
#
# ##############################################
# Contato 2:
# 	Nome: gabriel
# 	Telefone: 61984849797
# 	Email: gabriel@gmail.com
# 	Twitter: gab_s
# 	Instagram: gabr_el
# ##############################################
#
#
# ##############################################
# Contato 3:
# 	Nome: kathleen
# 	Telefone: 61952523232
# 	Email: kath@gmail.com
# 	Twitter: kath_leen
# 	Instagram: kathle_en
# ##############################################
#
#
# ##############################################
# Contato 4:
# 	Nome: pedro
# 	Telefone: 61945457445
# 	Email: pedro@gmail.com
# 	Twitter: pedr_o
# 	Instagram: pe_dro
# ##############################################
#
#
# ##############################################
# Contato 5:
# 	Nome: kimmy
# 	Telefone: 61985653221
# 	Email: kimmy@gmail.com
# 	Twitter: kimmyartemis
# 	Instagram: kimm_y
# ##############################################
#
#
# ##############################################
# Contato 6:
# 	Nome: nivs
# 	Telefone: 11985856363
# 	Email: nivs@gmail.com
# 	Twitter: niv_s
# 	Instagram: nivan_junior
# ##############################################
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 3
# Digite o nome do contato a ser excluído: pedro
#
# ##############################################
# Nome: pedro
# Telefone: 61945457445
# Email: pedro@gmail.com
# Twitter: pedr_o
# Instagram: pe_dro
# ##############################################
#
# O contato foi apagado com sucesso!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 5
#
# ##############################################
# Contato 1:
# 	Nome: thalles
# 	Telefone: 61985859595
# 	Email: thalles@gmail.com
# 	Twitter: thalles1809
# 	Instagram: 1809thalles
# ##############################################
#
#
# ##############################################
# Contato 2:
# 	Nome: gabriel
# 	Telefone: 61984849797
# 	Email: gabriel@gmail.com
# 	Twitter: gab_s
# 	Instagram: gabr_el
# ##############################################
#
#
# ##############################################
# Contato 3:
# 	Nome: kathleen
# 	Telefone: 61952523232
# 	Email: kath@gmail.com
# 	Twitter: kath_leen
# 	Instagram: kathle_en
# ##############################################
#
#
# ##############################################
# Contato 4:
# 	Nome: kimmy
# 	Telefone: 61985653221
# 	Email: kimmy@gmail.com
# 	Twitter: kimmyartemis
# 	Instagram: kimm_y
# ##############################################
#
#
# ##############################################
# Contato 5:
# 	Nome: nivs
# 	Telefone: 11985856363
# 	Email: nivs@gmail.com
# 	Twitter: niv_s
# 	Instagram: nivan_junior
# ##############################################
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 2
#  O nome do contato a ser alterado: gabriel
#
# ##############################################
# Nome: gabriel
# Telefone: 61984849797
# Email: gabriel@gmail.com
# Twitter: gab_s
# Instagram: gabr_el
# #############################################
#
#  Novo nome: bell
#  Telefone do contato: 6198452134
#  E-mail do contato: bell@gmail.com
#  Twitter do contato: bell_s
#  Instagram do contato: B_ell
#
# Os dados do contato bell, foram alterados com suceso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 2
#  O nome do contato a ser alterado: kimmy
#
# ##############################################
# Nome: kimmy
# Telefone: 61985653221
# Email: kimmy@gmail.com
# Twitter: kimmyartemis
# Instagram: kimm_y
# #############################################
#
#  Novo nome: Kimberli
#  Telefone do contato: 61965648782
#  E-mail do contato: kimmyArtemis@gmail.com
#  Twitter do contato: Kimmy_nha
#  Instagram do contato: Kimmy_Artemis
#
# Os dados do contato kimberli, foram alterados com suceso!
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 5
#
# ##############################################
# Contato 1:
# 	Nome: thalles
# 	Telefone: 61985859595
# 	Email: thalles@gmail.com
# 	Twitter: thalles1809
# 	Instagram: 1809thalles
# ##############################################
#
#
# ##############################################
# Contato 2:
# 	Nome: bell
# 	Telefone: 6198452134
# 	Email: bell@gmail.com
# 	Twitter: bell_s
# 	Instagram: b_ell
# ##############################################
#
#
# ##############################################
# Contato 3:
# 	Nome: kathleen
# 	Telefone: 61952523232
# 	Email: kath@gmail.com
# 	Twitter: kath_leen
# 	Instagram: kathle_en
# ##############################################
#
#
# ##############################################
# Contato 4:
# 	Nome: kimberli
# 	Telefone: 61965648782
# 	Email: kimmyartemis@gmail.com
# 	Twitter: kimmy_nha
# 	Instagram: kimmy_artemis
# ##############################################
#
#
# ##############################################
# Contato 5:
# 	Nome: nivs
# 	Telefone: 11985856363
# 	Email: nivs@gmail.com
# 	Twitter: niv_s
# 	Instagram: nivan_junior
# ##############################################
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------
# #####   Agenda Telefônica   #####
# ##### 1 - Adicionar contato #####
# ##### 2 - Alterar contato   #####
# ##### 3 - Excluir contato   #####
# ##### 4 - Buscar contato    #####
# ##### 5 - listar contato    #####
# ##### 6 - Sair              #####
# ---------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Escolha uma das opções a seguir ~> 6
#
# ###################################################
# Saindo do Programa...
# Execução finalizada com sucesso !
# ###################################################

# %% [markdown]
# ![Cadastro 1.png](data:image/png;base64,...)

# %% [markdown]
# ![Cadastro 2.png](data:image/png;base64,...)

# %% [markdown]
# ![Cadastro 3.png](data:image/png;base64,...)

# %% [markdown]
# ![Cadastro 5.png](data:image/png;base64,...)

# %% [markdown]
# ![Cadastro 5.png](data:image/png;base64,...)

# %% [markdown]
# ![Cadastro 6.png](data:image/png;base64,...)

# %% [markdown]
# ![Listagem 1 a 4.png](data:image/png;base64,...)

# %% [markdown]
# ![Listagem 5 a 6.png](data:image/png;base64,...)

# %% [markdown]
# ![Exclusão 1.png](data:image/png;base64,...)

# %% [markdown]
# ![Alteração 1.png](data:image/png;base64,...)

# %% [markdown]
# ![Alteração 2.png](data:image/png;base64,...)

# %% [markdown]
# ![Listagem 1 a 4 - 2.png](data:image/png;base64,...)

# %% [markdown]
# ![Listagem 5 - 2.png](data:image/png;base64,...)
